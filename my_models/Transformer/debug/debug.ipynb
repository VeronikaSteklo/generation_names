# %%
import pandas as pd

# %%
text1 = "сидя в тюрьме стала бисексуалкой. она была моей ровестницей и когда нам было по 40 лет она мне заявила что уходит жить к любовнице с которой сидела так как её любит . меня же она никогда не любила, почему была со мной не понятно."
title1 = "девять лет прожил с воровайкой и наркоманкой"

text2 = "я чувствую, что и в жизни, несмотря на резкие повороты, изломы пути, должна существовать глубокая связь между разными этапами. эта моя уверенность вступила в противоречие с фактами, но не усомнилась в себе, а потребовала объяснений. что общего между такими разными отрезками моей жизни?.."
title2 = "монолог о пути автобиографическое "

text3 = "перед новым годом, когда грань между мирами стирается и в наш мир может прийти как хорошее, так и плохое. вот и повадились в одной деревне мертвяки из могил вставать да к родным приходить. но родные таким гостям совсем не обрадовались."
title3 = "город мертвых"

text4 = "но потом и дети попали в руки врагов. хан отдал их рябой хромой старухе и велел покончить с киргизами. но когда рябая хромая старуха уже подвела их к берегу энесая, из леса вышла матка маралья и стала просить отдать детей."
title4 = "белый пароход"

df = pd.DataFrame({
    'text': [text1] * 25 + [text2] * 25 + [text3] * 25 + [text4] * 25,
    'title': [title1] * 25 + [title2] * 25 + [title3] * 25 + [title4] * 25,
})

df.to_csv("debug_train.csv", index=False)
